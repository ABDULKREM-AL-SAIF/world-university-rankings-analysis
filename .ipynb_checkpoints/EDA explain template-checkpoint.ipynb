# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
shangahai_rank_df = pd.read_excel("Data/shanghai Ranking.xlsx")
times_rank_df = pd.read_excel("Data/Times Higher Education.xlsx")
world_rank_df = pd.read_excel("Data/Word Rank University.xlsx")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
shangahai_rank_df
# Out:
#        Ranking                                University Name  \
# 1            1                             Harvard University
# 2            2                            Stanford University
# 3            3    Massachusetts Institute of Technology (MIT)
# 4            4                        University of Cambridge
# 5            5             University of California, Berkeley
# ...        ...                                            ...
# 996   901-1000                        University of Wuppertal
# 997   901-1000                Warsaw University of Technology
# 998   901-1000  Western Norway University of Applied Sciences
# 999   901-1000   Wroclaw University of Science and Technology
# 1000  901-1000                              Yantai University
#
#      National/Regional Rank  Total Score  \
# 1                         1        100.0
# 2                         2         76.8
# 3                         3         70.1
# 4                         1         69.6
# 5                         4         65.3
# ...                     ...          ...
# 996                   46-47          0.0
# 997                    7-11          0.0
# 998                     6-7          0.0
# 999                    7-11          0.0
# 1000                148-163          0.0
#
#                                                    LOGO  \
# 1     http://www.shanghairanking.com/_uni/logo/032bd...
# 2     http://www.shanghairanking.com/_uni/logo/13de8...
# 3     http://www.shanghairanking.com/_uni/logo/79165...
# 4     http://www.shanghairanking.com/_uni/logo/8d986...
# 5     http://www.shanghairanking.com/_uni/logo/0ff17...
# ...                                                 ...
# 996   http://www.shanghairanking.com/_uni/logo/2ab2f...
# 997   http://www.shanghairanking.com/_uni/logo/a347c...
# 998   http://www.shanghairanking.com/_uni/logo-jpg/d...
# 999   http://www.shanghairanking.com/_uni/logo/ed480...
# 1000  http://www.shanghairanking.com/_uni/logo/78347...
#
#                                      University Detail
# 1     http://www.shanghairanking.com/institution/har...
# 2     http://www.shanghairanking.com/institution/sta...
# 3     http://www.shanghairanking.com/institution/mas...
# 4     http://www.shanghairanking.com/institution/uni...
# 5     http://www.shanghairanking.com/institution/uni...
# ...                                                 ...
# 996   http://www.shanghairanking.com/institution/uni...
# 997   http://www.shanghairanking.com/institution/war...
# 998   http://www.shanghairanking.com/institution/wes...
# 999   http://www.shanghairanking.com/institution/wro...
# 1000  http://www.shanghairanking.com/institution/yan...
#
# [1000 rows x 6 columns]

# %%
times_rank_df
# Out:
#        Rank                       University Name   \
# 1         1              Western Sydney University
# 2         2               University of Manchester
# 3         3                     Queen’s University
# 4         4              Universiti Sains Malaysia
# 5         5                 University of Tasmania
# ...     ...                                    ...
# 1587  1001+                       Zarqa University
# 1588  1001+  Zewail City of Science and Technology
# 1589  1001+  Zhytomyr Ivan Franko State University
# 1590  1001+                   University of Žilina
# 1591  1001+     Zonguldak Bülent Ecevit University
#
#                          ranking-institution-title href        Location  \
# 1     https://www.timeshighereducation.com/world-uni...       Australia
# 2     https://www.timeshighereducation.com/world-uni...  United Kingdom
# 3     https://www.timeshighereducation.com/world-uni...          Canada
# 4     https://www.timeshighereducation.com/world-uni...        Malaysia
# 5     https://www.timeshighereducation.com/world-uni...       Australia
# ...                                                 ...             ...
# 1587  https://www.timeshighereducation.com/world-uni...          Jordan
# 1588  https://www.timeshighereducation.com/world-uni...           Egypt
# 1589  https://www.timeshighereducation.com/world-uni...         Ukraine
# 1590  https://www.timeshighereducation.com/world-uni...        Slovakia
# 1591  https://www.timeshighereducation.com/world-uni...          Turkey
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 1                         5.0                   80.3
# 2                        15.0                   97.4
# 3                         2.0                   90.6
# 4                        16.0                   94.1
# 5                        13.0                   92.8
# ...                       ...                    ...
# 1587                      NaN                    NaN
# 1588                      3.0              44.7–54.5
# 1589                      NaN                    NaN
# 1590                     11.0              20.9–38.4
# 1591                     12.0              49.4–58.6
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 1                          12.0                     93.4
# 2                          12.0                     92.9
# 3                          16.0                     93.4
# 4                           2.0                     86.4
# 5                          15.0                     96.2
# ...                         ...                      ...
# 1587                        NaN                      NaN
# 1588                        7.0                11.1–38.6
# 1589                       10.0                 3.9–25.5
# 1590                        NaN                      NaN
# 1591                        NaN                      NaN
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 1                          15.0                     96.7
# 2                          11.0                     92.2
# 3                          11.0                     91.0
# 4                           1.0                     84.9
# 5                          14.0                     95.1
# ...                         ...                      ...
# 1587                        1.0                23.3–38.1
# 1588                        NaN                      NaN
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
# 1591                        NaN                      NaN
#
#      sdg-score-multi__value 4    scores  sdg-score-multi__number 5  \
# 1                        98.8      99.4                        NaN
# 2                        94.8      97.5                        NaN
# 3                        92.6      97.2                        NaN
# 4                        97.8      96.9                        NaN
# 5                        96.3      96.6                        NaN
# ...                       ...       ...                        ...
# 1587                 1.5–45.2  7.9–53.8                        NaN
# 1588                45.3–53.3  7.9–53.8                        1.0
# 1589                 1.5–45.2  7.9–53.8                        NaN
# 1590                 1.5–45.2  7.9–53.8                        NaN
# 1591                 1.5–45.2  7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# ...                       ...                        ...
# 1587                      NaN                        4.0
# 1588                54.5–60.1                        NaN
# 1589                      NaN                        8.0
# 1590                      NaN                        9.0
# 1591                      NaN                        7.0
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# ...                       ...                        ...
# 1587                43.6–50.9                        3.0
# 1588                      NaN                        NaN
# 1589                35.7–48.3                        5.0
# 1590                17.2–33.8                        NaN
# 1591                51.9–56.1                        3.0
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# ...                       ...                        ...
# 1587                32.1–44.6                        NaN
# 1588                      NaN                        NaN
# 1589                43.7–51.5                        NaN
# 1590                      NaN                        4.0
# 1591                54.7–63.8                        NaN
#
#      sdg-score-multi__value 8
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 1587                      NaN
# 1588                      NaN
# 1589                      NaN
# 1590                 2.8–35.7
# 1591                      NaN
#
# [1591 rows x 20 columns]

# %%
world_rank_df
# Out:
#         World Rank                                   University Names  \
# 0        1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1        2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2        3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3        4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4        5Top 0.1%  University of Oxford\n  Education: A+; Employa...
# ...            ...                                                ...
# 1995  1996Top 9.8%                      Chongqing Jiaotong University
# 1996  1997Top 9.8%              University of Arkansas at Little Rock
# 1997  1998Top 9.8%                         Van Yüzüncü Yıl University
# 1998  1999Top 9.8%                           Bharathidasan University
# 1999  2000Top 9.8%                         Gebze Technical University
#
#            Location   National Rank Educational Rank Employability Rank  \
# 0                USA              1                1                  1
# 1                USA              2                4                 12
# 2                USA              3               11                  4
# 3     United Kingdom              1                3                 25
# 4     United Kingdom              2                7                 27
# ...              ...            ...              ...                ...
# 1995           China            314                -                  -
# 1996             USA            332                -               1322
# 1997          Turkey             54                -                  -
# 1998           India             64                -                  -
# 1999          Turkey             55                -                  -
#
#      Faculty Rank Research Rank  Score
# 0               1             1  100.0
# 1               3             9   96.7
# 2               2             2   95.2
# 3               5            11   94.1
# 4               9             4   93.3
# ...           ...           ...    ...
# 1995            -          1917   66.0
# 1996            -          1920   66.0
# 1997            -          1919   66.0
# 1998            -          1922   66.0
# 1999            -          1923   66.0
#
# [2000 rows x 9 columns]

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
shangahai_rank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ranking                 1000 non-null   object
#  1   University Name         1000 non-null   object
#  2   National/Regional Rank  1000 non-null   object
#  3   Total Score             1000 non-null   float64
#  4   LOGO                    1000 non-null   object
#  5   University Detail       1000 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
shangahai_rank_df.describe()
# Out:
#        Total Score
# count  1000.000000
# mean      5.943500
# std      12.379624
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       7.500000
# max     100.000000

# %%
shangahai_rank_df.describe(include="object")
# Out:
#         Ranking    University Name National/Regional Rank  \
# count      1000               1000                   1000
# unique       93               1000                    136
# top     201-300  Yantai University                      1
# freq        100                  1                     59
#
#                                                      LOGO  \
# count                                                1000
# unique                                               1000
# top     http://www.shanghairanking.com/_uni/logo/78347...
# freq                                                    1
#
#                                        University Detail
# count                                                1000
# unique                                               1000
# top     http://www.shanghairanking.com/institution/yan...
# freq                                                    1

# %%
times_rank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            1591 non-null   object
#  1   University Name                 1591 non-null   object
#  2   ranking-institution-title href  1500 non-null   object
#  3   Location                        1500 non-null   object
#  4   sdg-score-multi__number         867 non-null    float64
#  5   sdg-score-multi__value          867 non-null    object
#  6   sdg-score-multi__number 2       826 non-null    float64
#  7   sdg-score-multi__value 2        825 non-null    object
#  8   sdg-score-multi__number 3       812 non-null    float64
#  9   sdg-score-multi__value 3        805 non-null    object
#  10  sdg-score-multi__value 4        1583 non-null   object
#  11  scores                          1591 non-null   object
#  12  sdg-score-multi__number 5       565 non-null    float64
#  13  sdg-score-multi__value 5        557 non-null    object
#  14  sdg-score-multi__number 6       498 non-null    float64
#  15  sdg-score-multi__value 6        496 non-null    object
#  16  sdg-score-multi__number 7       439 non-null    float64
#  17  sdg-score-multi__value 7        439 non-null    object
#  18  sdg-score-multi__number 8       483 non-null    float64
#  19  sdg-score-multi__value 8        483 non-null    object
# dtypes: float64(7), object(13)
# memory usage: 248.7+ KB

# %%
times_rank_df.describe()
# Out:
#        sdg-score-multi__number  sdg-score-multi__number 2  \
# count               867.000000                 826.000000
# mean                  8.193772                   8.446731
# std                   4.240660                   4.786111
# min                   1.000000                   1.000000
# 25%                   4.000000                   4.000000
# 50%                   9.000000                   8.000000
# 75%                  11.000000                  12.000000
# max                  16.000000                  16.000000
#
#        sdg-score-multi__number 3  sdg-score-multi__number 5  \
# count                 812.000000                 565.000000
# mean                    7.902709                   5.488496
# std                     4.403411                   3.151375
# min                     1.000000                   1.000000
# 25%                     5.000000                   3.000000
# 50%                     8.000000                   5.000000
# 75%                    11.000000                   8.000000
# max                    16.000000                  16.000000
#
#        sdg-score-multi__number 6  sdg-score-multi__number 7  \
# count                 498.000000                 439.000000
# mean                    6.777108                   7.596811
# std                     3.230968                   4.278980
# min                     1.000000                   1.000000
# 25%                     4.000000                   4.000000
# 50%                     6.000000                   7.000000
# 75%                     8.000000                  10.000000
# max                    16.000000                  16.000000
#
#        sdg-score-multi__number 8
# count                 483.000000
# mean                    5.962733
# std                     3.346928
# min                     3.000000
# 25%                     4.000000
# 50%                     4.000000
# 75%                     7.000000
# max                    16.000000

# %%
times_rank_df.describe(include="object")
# Out:
#          Rank                    University Name   \
# count    1591                                1591
# unique     64                                1591
# top     1001+  Zonguldak Bülent Ecevit University
# freq      591                                   1
#
#                            ranking-institution-title href Location  \
# count                                                1500     1500
# unique                                               1500      110
# top     https://www.timeshighereducation.com/world-uni...   Turkey
# freq                                                    1       79
#
#        sdg-score-multi__value sdg-score-multi__value 2  \
# count                     867                      825
# unique                    250                      236
# top                 73.0–87.2                45.2–58.6
# freq                       28                       22
#
#        sdg-score-multi__value 3 sdg-score-multi__value 4    scores  \
# count                       805                     1583      1591
# unique                      228                       87        64
# top                   48.4–57.7                 1.5–45.2  7.9–53.8
# freq                         20                      579       591
#
#        sdg-score-multi__value 5 sdg-score-multi__value 6  \
# count                       557                      496
# unique                      147                      143
# top                   44.7–54.5                48.4–57.7
# freq                         36                       23
#
#        sdg-score-multi__value 7 sdg-score-multi__value 8
# count                       439                      483
# unique                      113                      108
# top                   48.4–57.7                 2.8–35.7
# freq                         20                       33

# %%
world_rank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   World Rank          2000 non-null   object
#  1   University Names    2000 non-null   object
#  2   Location            2000 non-null   object
#  3   National Rank       2000 non-null   int64
#  4   Educational Rank    2000 non-null   object
#  5   Employability Rank  2000 non-null   object
#  6   Faculty Rank        2000 non-null   object
#  7   Research Rank       2000 non-null   object
#  8   Score               2000 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 140.8+ KB

# %%
world_rank_df.describe()
# Out:
#        National Rank       Score
# count    2000.000000  2000.00000
# mean       69.245000    71.75555
# std        85.538608     5.03880
# min         1.000000    66.00000
# 25%         9.750000    67.90000
# 50%        33.000000    70.40000
# 75%        89.000000    74.30000
# max       332.000000   100.00000

# %%
world_rank_df.describe(include="object")
# Out:
#           World Rank            University Names Location  Educational Rank  \
# count           2000                        2000      2000             2000
# unique          2000                        2000        95              439
# top     2000Top 9.8%  Gebze Technical University       USA                -
# freq               1                           1       332             1562
#
#        Employability Rank Faculty Rank Research Rank
# count                2000         2000          2000
# unique               1030          262          1935
# top                     -            -             -
# freq                  967         1727            66

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# Yes This Is What Customer Ask For

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# Yes This Is What Customer Ask For

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
shangahai_rank_df.duplicated().sum()
# Out:
# 0

# %%
times_rank_df.duplicated().sum()
# Out:
# 0

# %%
world_rank_df.duplicated().sum()
# Out:
# 0

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
shangahai_rank_df.isnull().sum()
# Out:
# Ranking                   0
# University Name           0
# National/Regional Rank    0
# Total Score               0
# LOGO                      0
# University Detail         0
# dtype: int64

# %%
times_rank_df.isnull().sum()
# Out:
# Rank                                 0
# University Name                      0
# ranking-institution-title href      91
# Location                            91
# sdg-score-multi__number            724
# sdg-score-multi__value             724
# sdg-score-multi__number 2          765
# sdg-score-multi__value 2           766
# sdg-score-multi__number 3          779
# sdg-score-multi__value 3           786
# sdg-score-multi__value 4             8
# scores                               0
# sdg-score-multi__number 5         1026
# sdg-score-multi__value 5          1034
# sdg-score-multi__number 6         1093
# sdg-score-multi__value 6          1095
# sdg-score-multi__number 7         1152
# sdg-score-multi__value 7          1152
# sdg-score-multi__number 8         1108
# sdg-score-multi__value 8          1108
# dtype: int64

# %%
world_rank_df.isnull().sum()
# Out:
# World Rank            0
# University Names      0
# Location              0
# National Rank         0
# Educational Rank      0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types

# %%
shangahai_rank_df
# Out:
#       Ranking                                University Name  \
# 0           1                             Harvard University
# 1           2                            Stanford University
# 2           3    Massachusetts Institute of Technology (MIT)
# 3           4                        University of Cambridge
# 4           5             University of California, Berkeley
# ..        ...                                            ...
# 995  901-1000                        University of Wuppertal
# 996  901-1000                Warsaw University of Technology
# 997  901-1000  Western Norway University of Applied Sciences
# 998  901-1000   Wroclaw University of Science and Technology
# 999  901-1000                              Yantai University
#
#     National/Regional Rank  Total Score  \
# 0                        1        100.0
# 1                        2         76.8
# 2                        3         70.1
# 3                        1         69.6
# 4                        4         65.3
# ..                     ...          ...
# 995                  46-47          0.0
# 996                   7-11          0.0
# 997                    6-7          0.0
# 998                   7-11          0.0
# 999                148-163          0.0
#
#                                                   LOGO  \
# 0    http://www.shanghairanking.com/_uni/logo/032bd...
# 1    http://www.shanghairanking.com/_uni/logo/13de8...
# 2    http://www.shanghairanking.com/_uni/logo/79165...
# 3    http://www.shanghairanking.com/_uni/logo/8d986...
# 4    http://www.shanghairanking.com/_uni/logo/0ff17...
# ..                                                 ...
# 995  http://www.shanghairanking.com/_uni/logo/2ab2f...
# 996  http://www.shanghairanking.com/_uni/logo/a347c...
# 997  http://www.shanghairanking.com/_uni/logo-jpg/d...
# 998  http://www.shanghairanking.com/_uni/logo/ed480...
# 999  http://www.shanghairanking.com/_uni/logo/78347...
#
#                                     University Detail
# 0    http://www.shanghairanking.com/institution/har...
# 1    http://www.shanghairanking.com/institution/sta...
# 2    http://www.shanghairanking.com/institution/mas...
# 3    http://www.shanghairanking.com/institution/uni...
# 4    http://www.shanghairanking.com/institution/uni...
# ..                                                 ...
# 995  http://www.shanghairanking.com/institution/uni...
# 996  http://www.shanghairanking.com/institution/war...
# 997  http://www.shanghairanking.com/institution/wes...
# 998  http://www.shanghairanking.com/institution/wro...
# 999  http://www.shanghairanking.com/institution/yan...
#
# [1000 rows x 6 columns]

# %%
times_rank_df
# Out:
#        Rank                       University Name   \
# 0         1              Western Sydney University
# 1         2               University of Manchester
# 2         3                     Queen’s University
# 3         4              Universiti Sains Malaysia
# 4         5                 University of Tasmania
# ...     ...                                    ...
# 1586  1001+                       Zarqa University
# 1587  1001+  Zewail City of Science and Technology
# 1588  1001+  Zhytomyr Ivan Franko State University
# 1589  1001+                   University of Žilina
# 1590  1001+     Zonguldak Bülent Ecevit University
#
#                          ranking-institution-title href        Location  \
# 0     https://www.timeshighereducation.com/world-uni...       Australia
# 1     https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2     https://www.timeshighereducation.com/world-uni...          Canada
# 3     https://www.timeshighereducation.com/world-uni...        Malaysia
# 4     https://www.timeshighereducation.com/world-uni...       Australia
# ...                                                 ...             ...
# 1586  https://www.timeshighereducation.com/world-uni...          Jordan
# 1587  https://www.timeshighereducation.com/world-uni...           Egypt
# 1588  https://www.timeshighereducation.com/world-uni...         Ukraine
# 1589  https://www.timeshighereducation.com/world-uni...        Slovakia
# 1590  https://www.timeshighereducation.com/world-uni...          Turkey
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 0                         5.0                   80.3
# 1                        15.0                   97.4
# 2                         2.0                   90.6
# 3                        16.0                   94.1
# 4                        13.0                   92.8
# ...                       ...                    ...
# 1586                      NaN                    NaN
# 1587                      3.0              44.7–54.5
# 1588                      NaN                    NaN
# 1589                     11.0              20.9–38.4
# 1590                     12.0              49.4–58.6
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 0                          12.0                     93.4
# 1                          12.0                     92.9
# 2                          16.0                     93.4
# 3                           2.0                     86.4
# 4                          15.0                     96.2
# ...                         ...                      ...
# 1586                        NaN                      NaN
# 1587                        7.0                11.1–38.6
# 1588                       10.0                 3.9–25.5
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 0                          15.0                     96.7
# 1                          11.0                     92.2
# 2                          11.0                     91.0
# 3                           1.0                     84.9
# 4                          14.0                     95.1
# ...                         ...                      ...
# 1586                        1.0                23.3–38.1
# 1587                        NaN                      NaN
# 1588                        NaN                      NaN
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
#
#      sdg-score-multi__value 4    scores  sdg-score-multi__number 5  \
# 0                        98.8      99.4                        NaN
# 1                        94.8      97.5                        NaN
# 2                        92.6      97.2                        NaN
# 3                        97.8      96.9                        NaN
# 4                        96.3      96.6                        NaN
# ...                       ...       ...                        ...
# 1586                 1.5–45.2  7.9–53.8                        NaN
# 1587                45.3–53.3  7.9–53.8                        1.0
# 1588                 1.5–45.2  7.9–53.8                        NaN
# 1589                 1.5–45.2  7.9–53.8                        NaN
# 1590                 1.5–45.2  7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1586                      NaN                        4.0
# 1587                54.5–60.1                        NaN
# 1588                      NaN                        8.0
# 1589                      NaN                        9.0
# 1590                      NaN                        7.0
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1586                43.6–50.9                        3.0
# 1587                      NaN                        NaN
# 1588                35.7–48.3                        5.0
# 1589                17.2–33.8                        NaN
# 1590                51.9–56.1                        3.0
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1586                32.1–44.6                        NaN
# 1587                      NaN                        NaN
# 1588                43.7–51.5                        NaN
# 1589                      NaN                        4.0
# 1590                54.7–63.8                        NaN
#
#      sdg-score-multi__value 8
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 1586                      NaN
# 1587                      NaN
# 1588                      NaN
# 1589                 2.8–35.7
# 1590                      NaN
#
# [1591 rows x 20 columns]

# %%
world_rank_df
# Out:
#         World Rank                                   University Names  \
# 0        1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1        2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2        3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3        4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4        5Top 0.1%  University of Oxford\n  Education: A+; Employa...
# ...            ...                                                ...
# 1995  1996Top 9.8%                      Chongqing Jiaotong University
# 1996  1997Top 9.8%              University of Arkansas at Little Rock
# 1997  1998Top 9.8%                         Van Yüzüncü Yıl University
# 1998  1999Top 9.8%                           Bharathidasan University
# 1999  2000Top 9.8%                         Gebze Technical University
#
#            Location   National Rank Educational Rank Employability Rank  \
# 0                USA              1                1                  1
# 1                USA              2                4                 12
# 2                USA              3               11                  4
# 3     United Kingdom              1                3                 25
# 4     United Kingdom              2                7                 27
# ...              ...            ...              ...                ...
# 1995           China            314                -                  -
# 1996             USA            332                -               1322
# 1997          Turkey             54                -                  -
# 1998           India             64                -                  -
# 1999          Turkey             55                -                  -
#
#      Faculty Rank Research Rank  Score
# 0               1             1  100.0
# 1               3             9   96.7
# 2               2             2   95.2
# 3               5            11   94.1
# 4               9             4   93.3
# ...           ...           ...    ...
# 1995            -          1917   66.0
# 1996            -          1920   66.0
# 1997            -          1919   66.0
# 1998            -          1922   66.0
# 1999            -          1923   66.0
#
# [2000 rows x 9 columns]

# %%
# go to clean them

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# Which universities are ranked in the top 10 globally ?

# %%
shangahai_rank_df[['Ranking', 'University Name']].head(10)
# Out:
#   Ranking                              University Name
# 0       1                           Harvard University
# 1       2                          Stanford University
# 2       3  Massachusetts Institute of Technology (MIT)
# 3       4                      University of Cambridge
# 4       5           University of California, Berkeley
# 5       6                         Princeton University
# 6       7                         University of Oxford
# 7       8                          Columbia University
# 8       9           California Institute of Technology
# 9      10                        University of Chicago

# %%
times_rank_df[['Rank', 'University Name ']].head(10)
# Out:
#   Rank                  University Name
# 0    1         Western Sydney University
# 1    2          University of Manchester
# 2    3                Queen’s University
# 3    4         Universiti Sains Malaysia
# 4    5            University of Tasmania
# 5    6  Arizona State University (Tempe)
# 6   =7             University of Alberta
# 7   =7                   RMIT University
# 8   =9                Aalborg University
# 9   =9            University of Victoria

# %%
world_rank_df[['World Rank', 'University Names']].head(10)
# Out:
#    World Rank                                   University Names
# 0   1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1   2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2   3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3   4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4   5Top 0.1%  University of Oxford\n  Education: A+; Employa...
# 5   6Top 0.1%  Princeton University\n  Education: A+; Employa...
# 6   7Top 0.1%  University of Chicago\n  Education: A+; Employ...
# 7   8Top 0.1%  Columbia University\n  Education: A+; Employab...
# 8   9Top 0.1%  University of Pennsylvania\n  Education: A; Em...
# 9  10Top 0.1%  Yale University\n  Education: A+; Employabilit...

# %%
# Which universities are ranked in the top 10 for employment outcomes?

# %%
world_rank_df[world_rank_df['Employability Rank'] > 0].sort_values('Employability Rank', ascending = True).head(10)
# Out:
#      World Rank                                   University Names  \
# 0             1                                 Harvard University
# 119         120                                             INSEAD
# 210         211                Institut national du service public
# 2             3                                Stanford University
# 273         274         China Europe International Business School
# 12           13                                University of Tokyo
# 279         280                                          HEC Paris
# 8             9                         University of Pennsylvania
# 44           45                    Institut Polytechnique de Paris
# 405         406  International Institute for Management Develop...
#
#        Location   National Rank  Educational Rank  Employability Rank  \
# 0            USA              1                 1                   1
# 119       France              6                 0                   2
# 210       France             11                 0                   3
# 2            USA              3                11                   4
# 273        China             32                 0                   5
# 12         Japan              1                37                   6
# 279       France             15                 0                   7
# 8            USA              7                14                   8
# 44        France              5               102                   9
# 405  Switzerland              8                 0                  10
#
#      Faculty Rank  Research Rank  Score
# 0               1              1  100.0
# 119             0           1710   81.1
# 210             0              0   78.5
# 2               2              2   95.2
# 273             0              0   77.3
# 12            113             30   89.8
# 279             0              0   77.2
# 8              45             12   91.2
# 44            188            370   85.1
# 405             0              0   75.3

# %%
# What positions do universities in Saudi Arabia hold within the global rankings?

# %%
shangahai_rank_df[shangahai_rank_df['National/Regional Rank'] == 'Saudi Arabia']
# Out:
# Empty DataFrame
# Columns: [Ranking, University Name, National/Regional Rank, Total Score, LOGO, University Detail ]
# Index: []

# %%
times_rank_df[times_rank_df['Location'] == 'Saudi Arabia']
# Out:
#           Rank                                   University Name   \
# 136    101–200  King Abdullah University of Science and Techno...
# 137    101–200                             King Faisal University
# 164    101–200                Prince Mohammad Bin Fahd University
# 205    201–300                               AlMaarefa University
# 243    201–300             Imam Abdulrahman Bin Faisal University
# 244    201–300          Imam Mohammad Ibn Saud Islamic University
# 251    201–300     King Fahd University of Petroleum and Minerals
# 378    301–400                     Prince Sultan University (PSU)
# 482    401–600                             King Khalid University
# 539    401–600                                  Qassim University
# 606    601–800                                Alfaisal University
# 623    601–800                          Batterjee Medical College
# 745    601–800             Prince Sattam Bin Abdulaziz University
# 755    601–800                        Saudi Electronic University
# 808   801–1000                                 Al-Baha University
# 837   801–1000                                University of Bisha
# 866   801–1000                                 University of Hail
# 881   801–1000                               University of Jeddah
# 989   801–1000                             Umm Al-Qura University
# 1034     1001+                              Al Yamamah University
# 1095     1001+              University of Business and Technology
# 1156     1001+                                   Effat University
# 1236     1001+                      Islamic University of Madinah
# 1337     1001+                                  Najran University
# 1485     1001+                                University of Tabuk
#
#                          ranking-institution-title href      Location  \
# 136   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 137   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 164   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 205   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 243   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 244   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 251   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 378   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 482   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 539   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 606   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 623   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 745   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 755   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 808   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 837   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 866   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 881   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 989   https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 1034  https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 1095  https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 1156  https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 1236  https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 1337  https://www.timeshighereducation.com/world-uni...  Saudi Arabia
# 1485  https://www.timeshighereducation.com/world-uni...  Saudi Arabia
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 136                       NaN                    NaN
# 137                       2.0                   77.7
# 164                      10.0              65.2–73.3
# 205                       NaN                    NaN
# 243                       5.0              61.5–66.9
# 244                       NaN                    NaN
# 251                       8.0                   75.0
# 378                       8.0                   74.6
# 482                       6.0                   69.4
# 539                       1.0                   79.1
# 606                       9.0              73.0–87.2
# 623                       NaN                    NaN
# 745                       NaN                    NaN
# 755                      12.0              49.4–58.6
# 808                       NaN                    NaN
# 837                       3.0              44.7–54.5
# 866                       NaN                    NaN
# 881                       5.0              56.1–61.4
# 989                       NaN                    NaN
# 1034                      NaN                    NaN
# 1095                     10.0              51.8–57.5
# 1156                      5.0              51.6–56.0
# 1236                      NaN                    NaN
# 1337                      3.0              32.1–44.6
# 1485                      NaN                    NaN
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 136                        14.0                     93.7
# 137                         7.0                     78.6
# 164                         8.0                62.4–66.3
# 205                         1.0                     71.5
# 243                         NaN                      NaN
# 244                        16.0                70.0–77.0
# 251                         NaN                      NaN
# 378                        16.0                63.7–69.9
# 482                         NaN                      NaN
# 539                         8.0                57.8–62.2
# 606                         3.0                68.3–73.4
# 623                         NaN                      NaN
# 745                         NaN                      NaN
# 755                         NaN                      NaN
# 808                         NaN                      NaN
# 837                         7.0                38.7–51.8
# 866                         3.0                54.7–63.8
# 881                         NaN                      NaN
# 989                         NaN                      NaN
# 1034                        NaN                      NaN
# 1095                        NaN                      NaN
# 1156                        NaN                      NaN
# 1236                       12.0                26.1–49.1
# 1337                        5.0                 5.0–21.9
# 1485                       15.0                47.8–59.4
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 136                         NaN                      NaN
# 137                         NaN                      NaN
# 164                        14.0                     73.7
# 205                         NaN                      NaN
# 243                         6.0                     73.7
# 244                         NaN                      NaN
# 251                        14.0                     75.0
# 378                         5.0                43.7–51.5
# 482                         NaN                      NaN
# 539                         4.0                     73.1
# 606                         4.0                43.6–50.9
# 623                         NaN                      NaN
# 745                         3.0                54.7–63.8
# 755                         NaN                      NaN
# 808                         NaN                      NaN
# 837                         NaN                      NaN
# 866                         NaN                      NaN
# 881                         NaN                      NaN
# 989                         NaN                      NaN
# 1034                        5.0                34.4–43.6
# 1095                        NaN                      NaN
# 1156                        NaN                      NaN
# 1236                        NaN                      NaN
# 1337                        NaN                      NaN
# 1485                        8.0                48.4–57.7
#
#      sdg-score-multi__value 4     scores  sdg-score-multi__number 5  \
# 136                      95.9  82.2–88.2                        NaN
# 137                 81.9–86.9  82.2–88.2                        1.0
# 164                      90.7  82.2–88.2                        NaN
# 205                 81.9–86.9  76.8–82.1                        NaN
# 243                      89.0  76.8–82.1                        3.0
# 244                 81.9–86.9  76.8–82.1                        8.0
# 251                 81.9–86.9  76.8–82.1                        NaN
# 378                 75.6–81.7  72.7–76.7                        NaN
# 482                 53.4–61.0  66.9–72.6                        NaN
# 539                 81.9–86.9  66.9–72.6                        NaN
# 606                 45.3–53.3  59.7–66.7                        NaN
# 623                 45.3–53.3  59.7–66.7                        NaN
# 745                 61.1–70.5  59.7–66.7                        5.0
# 755                 45.3–53.3  59.7–66.7                        4.0
# 808                 53.4–61.0  53.9–59.6                        3.0
# 837                  1.5–45.2  53.9–59.6                        NaN
# 866                 53.4–61.0  53.9–59.6                        NaN
# 881                 45.3–53.3  53.9–59.6                        NaN
# 989                 61.1–70.5  53.9–59.6                        3.0
# 1034                 1.5–45.2   7.9–53.8                        NaN
# 1095                53.4–61.0   7.9–53.8                        5.0
# 1156                45.3–53.3   7.9–53.8                        3.0
# 1236                 1.5–45.2   7.9–53.8                        8.0
# 1337                 1.5–45.2   7.9–53.8                        NaN
# 1485                53.4–61.0   7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 136                       NaN                        6.0
# 137                      80.1                        NaN
# 164                       NaN                        NaN
# 205                       NaN                        8.0
# 243                      89.6                        NaN
# 244                 62.4–66.3                        NaN
# 251                       NaN                        NaN
# 378                       NaN                        NaN
# 482                       NaN                        NaN
# 539                       NaN                        NaN
# 606                       NaN                        NaN
# 623                       NaN                        5.0
# 745                 43.7–51.5                        NaN
# 755                 62.6–66.5                        NaN
# 808                 32.1–44.6                        8.0
# 837                       NaN                        NaN
# 866                       NaN                        4.0
# 881                       NaN                        8.0
# 989                 63.9–68.2                        9.0
# 1034                      NaN                        NaN
# 1095                34.4–43.6                        NaN
# 1156                32.1–44.6                        NaN
# 1236                 1.4–35.6                        4.0
# 1337                      NaN                        NaN
# 1485                      NaN                        NaN
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 136                      88.0                        NaN
# 137                       NaN                        NaN
# 164                       NaN                        NaN
# 205                 62.4–66.3                        3.0
# 243                       NaN                        NaN
# 244                       NaN                        NaN
# 251                       NaN                        NaN
# 378                       NaN                        NaN
# 482                       NaN                        NaN
# 539                       NaN                        NaN
# 606                       NaN                        NaN
# 623                 43.7–51.5                        NaN
# 745                       NaN                        NaN
# 755                       NaN                        NaN
# 808                 48.4–57.7                        NaN
# 837                       NaN                        NaN
# 866                 43.6–50.9                        1.0
# 881                 48.4–57.7                        NaN
# 989                 17.2–33.8                        NaN
# 1034                      NaN                        8.0
# 1095                      NaN                        NaN
# 1156                      NaN                       10.0
# 1236                35.8–43.5                        NaN
# 1337                      NaN                        NaN
# 1485                      NaN                        NaN
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 136                       NaN                        7.0
# 137                       NaN                        NaN
# 164                       NaN                        NaN
# 205                      81.6                        NaN
# 243                       NaN                        NaN
# 244                       NaN                        4.0
# 251                       NaN                        9.0
# 378                       NaN                        NaN
# 482                       NaN                        NaN
# 539                       NaN                        NaN
# 606                       NaN                        NaN
# 623                       NaN                        3.0
# 745                       NaN                        NaN
# 755                       NaN                       10.0
# 808                       NaN                        4.0
# 837                       NaN                        4.0
# 866                 38.2–49.4                        NaN
# 881                       NaN                        4.0
# 989                       NaN                        4.0
# 1034                48.4–57.7                       10.0
# 1095                      NaN                        8.0
# 1156                40.0–51.7                        NaN
# 1236                      NaN                        NaN
# 1337                      NaN                        4.0
# 1485                      NaN                        4.0
#
#      sdg-score-multi__value 8
# 136                      70.9
# 137                       NaN
# 164                       NaN
# 205                       NaN
# 243                       NaN
# 244                      82.2
# 251                      95.6
# 378                       NaN
# 482                       NaN
# 539                       NaN
# 606                       NaN
# 623                 63.9–68.2
# 745                       NaN
# 755                 57.6–65.1
# 808                 51.0–58.6
# 837                 62.6–66.5
# 866                       NaN
# 881                 62.6–66.5
# 989                 43.6–50.9
# 1034                51.8–57.5
# 1095                62.4–66.3
# 1156                      NaN
# 1236                      NaN
# 1337                43.6–50.9
# 1485                43.6–50.9

# %%
world_rank_df[world_rank_df['Location '] == 'Saudi Arabia']
# Out:
#       World Rank                                   University Names  \
# 244          245                          King Abdulaziz University
# 278          279  King Abdullah University of Science and Techno...
# 351          352                               King Saud University
# 656          657     King Fahd University of Petroleum and Minerals
# 1310        1311  King Saud bin Abdulaziz University for Health ...
# 1446        1447                             King Khalid University
# 1508        1509                                    Taif University
# 1546        1547             Imam Abdulrahman Bin Faisal University
# 1585        1586                                  Taibah University
# 1710        1711             Prince Sattam Bin Abdulaziz University
# 1741        1742                             Umm Al-Qura University
# 1761        1762                                Alfaisal University
# 1810        1811                                   Jazan University
# 1906        1907                                  Qassim University
# 1973        1974                                University of Tabuk
# 1978        1979                             King Faisal University
#
#          Location   National Rank  Educational Rank  Employability Rank  \
# 244   Saudi Arabia              1                 0                1330
# 278   Saudi Arabia              2                 0                   0
# 351   Saudi Arabia              3                 0                 344
# 656   Saudi Arabia              4                 0                 107
# 1310  Saudi Arabia              5                 0                   0
# 1446  Saudi Arabia              6                 0                   0
# 1508  Saudi Arabia              7                 0                   0
# 1546  Saudi Arabia              8                 0                   0
# 1585  Saudi Arabia              9                 0                   0
# 1710  Saudi Arabia             10                 0                   0
# 1741  Saudi Arabia             11                 0                   0
# 1761  Saudi Arabia             12                 0                   0
# 1810  Saudi Arabia             13                 0                   0
# 1906  Saudi Arabia             14                 0                   0
# 1973  Saudi Arabia             15                 0                   0
# 1978  Saudi Arabia             16                 0                   0
#
#       Faculty Rank  Research Rank  Score
# 244              0            186   77.8
# 278            171            297   77.2
# 351              0            332   76.1
# 656              0            792   72.8
# 1310             0           1255   68.8
# 1446             0           1385   68.1
# 1508             0           1445   67.9
# 1546             0           1484   67.7
# 1585             0           1520   67.5
# 1710             0           1636   67.0
# 1741             0           1666   66.9
# 1761             0           1688   66.8
# 1810             0           1737   66.6
# 1906             0           1830   66.3
# 1973             0           1896   66.1
# 1978             0           1903   66.0

# %%
UoS_1 = times_rank_df[times_rank_df['Location'] == 'Saudi Arabia']

# %%
UoS_2 = world_rank_df[world_rank_df['Location '] == 'Saudi Arabia']

# %%
UoS_1 = list(UoS_1['University Name '])

# %%
UoS_2 = list(UoS_2['University Names'])

# %%
shangahai_rank_df[shangahai_rank_df['University Name'].isin(UoS_1)]
# Out:
#      Ranking                         University Name National/Regional Rank  \
# 631  601-700                  King Khalid University                      6
# 855  801-900  Prince Sattam Bin Abdulaziz University                      7
#
#      Total Score                                               LOGO  \
# 631          0.0  http://www.shanghairanking.com/_uni/logo/1486b...
# 855          0.0  http://www.shanghairanking.com/_uni/logo/d5282...
#
#                                     University Detail
# 631  http://www.shanghairanking.com/institution/kin...
# 855  http://www.shanghairanking.com/institution/pri...

# %%
shangahai_rank_df[shangahai_rank_df['University Name'].isin(UoS_2)]
# Out:
#      Ranking                                    University Name  \
# 109  101-150                          King Abdulaziz University
# 110  101-150                               King Saud University
# 222  201-300  King Abdullah University of Science and Techno...
# 446  401-500                                    Taif University
# 631  601-700                             King Khalid University
# 855  801-900             Prince Sattam Bin Abdulaziz University
#
#     National/Regional Rank  Total Score  \
# 109                    1-2          0.0
# 110                    1-2          0.0
# 222                      3          0.0
# 446                    4-5          0.0
# 631                      6          0.0
# 855                      7          0.0
#
#                                                   LOGO  \
# 109  http://www.shanghairanking.com/_uni/logo-jpg/c...
# 110  http://www.shanghairanking.com/_uni/logo/a8ed5...
# 222  http://www.shanghairanking.com/_uni/logo/aebd2...
# 446  http://www.shanghairanking.com/_uni/logo/df754...
# 631  http://www.shanghairanking.com/_uni/logo/1486b...
# 855  http://www.shanghairanking.com/_uni/logo/d5282...
#
#                                     University Detail
# 109  http://www.shanghairanking.com/institution/kin...
# 110  http://www.shanghairanking.com/institution/kin...
# 222  http://www.shanghairanking.com/institution/kin...
# 446  http://www.shanghairanking.com/institution/tai...
# 631  http://www.shanghairanking.com/institution/kin...
# 855  http://www.shanghairanking.com/institution/pri...

# %%
# can you recommend a country that appears to have a high concentration of top-ranked universities?

# %%
times_rank_df[:100].groupby('Location').size()
# Out:
# Location
# Australia         15
# Canada            16
# China              1
# Denmark            1
# Hong Kong          1
# India              1
# Indonesia          1
# Ireland            4
# Italy              2
# Japan              2
# Malaysia           1
# Mexico             2
# New Zealand        7
# Portugal           1
# South Africa       2
# South Korea        3
# Sweden             1
# Taiwan             3
# Thailand           4
# Turkey             1
# United Kingdom    25
# United States      6
# dtype: int64

# %%
world_rank_df[:100].groupby('Location ').size()
# Out:
# Location
# Australia          2
# Canada             4
# China              6
# Denmark            1
# France             5
# Germany            6
# Israel             2
# Japan              3
# Netherlands        4
# Norway             1
# Singapore          1
# South Korea        1
# Sweden             2
# Switzerland        3
# USA               50
# United Kingdom     9
# dtype: int64

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
shangahai_rank_df.index = shangahai_rank_df.index + 1 # Add 1 To Index To Use It For Ranking

# %%
times_rank_df.index = times_rank_df.index + 1 # Add 1 To Index To Use It For Ranking

# %%
world_rank_df.index = world_rank_df.index + 1 # Add 1 To Index To Use It For Ranking

# %%
# Remove Top From World Rank And Change Data Type To Integer
world_rank_df['World Rank'] = world_rank_df['World Rank'].map(lambda x : int(x.split("T")[0]))

# %%
# Replace - To 0 From Educational Rank Column Befor Change Data Type
world_rank_df['Educational Rank'] = world_rank_df['Educational Rank'].replace('-', 0)

# %%
# Change Data Type For Educational Rank Column To Integer
world_rank_df['Educational Rank'] = world_rank_df['Educational Rank'].astype(int)

# %%
# Replace - To 0 From Employability Rank Column Befor Change Data Type
world_rank_df['Employability Rank'] = world_rank_df['Employability Rank'].replace('-', 0)

# %%
# Change Data Type For Employability Rank Column To Integer
world_rank_df['Employability Rank'] = world_rank_df['Employability Rank'].astype(int)

# %%
# Replace - To 0 From Faculty Rank Column Befor Change Data Type
world_rank_df['Faculty Rank'] = world_rank_df['Faculty Rank'].replace('-', 0)

# %%
# Change Data Type For Faculty Rank Column To Integer
world_rank_df['Faculty Rank'] = world_rank_df['Faculty Rank'].astype(int)

# %%
# Replace - To 0 From Research Rank Column Befor Change Data Type
world_rank_df['Research Rank'] = world_rank_df['Research Rank'].replace('-', 0)

# %%
# Change Data Type For Research Rank Column To Integer
world_rank_df['Research Rank'] = world_rank_df['Research Rank'].astype(int)

# %%
def name_change(x):
    if "\n" in x:  
        return x.split("\n")[0]  
    else:
        return x

world_rank_df["University Names"] = world_rank_df["University Names"].apply(name_change)

world_rank_df.head(20)
# Out:
#     World Rank                       University Names       Location   \
# 1            1                     Harvard University             USA
# 2            2  Massachusetts Institute of Technology             USA
# 3            3                    Stanford University             USA
# 4            4                University of Cambridge  United Kingdom
# 5            5                   University of Oxford  United Kingdom
# 6            6                   Princeton University             USA
# 7            7                  University of Chicago             USA
# 8            8                    Columbia University             USA
# 9            9             University of Pennsylvania             USA
# 10          10                        Yale University             USA
# 11          11     California Institute of Technology             USA
# 12          12     University of California, Berkeley             USA
# 13          13                    University of Tokyo           Japan
# 14          14                     Cornell University             USA
# 15          15                Northwestern University             USA
# 16          16      University of Michigan, Ann Arbor             USA
# 17          17               Johns Hopkins University             USA
# 18          18  University of California, Los Angeles             USA
# 19          19              University College London  United Kingdom
# 20          20                        Duke University             USA
#
#     National Rank  Educational Rank  Employability Rank  Faculty Rank  \
# 1               1                 1                   1             1
# 2               2                 4                  12             3
# 3               3                11                   4             2
# 4               1                 3                  25             5
# 5               2                 7                  27             9
# 6               4                 5                  16             6
# 7               5                 8                  15            22
# 8               6                12                  14            10
# 9               7                14                   8            45
# 10              8                 6                  35            13
# 11              9                 2                  96             7
# 12             10                 9                  59             4
# 13              1                37                   6           113
# 14             11                16                  29            18
# 15             12                99                  17            31
# 16             13                32                  40            62
# 17             14                22                 192            20
# 18             15                31                  63            16
# 19              3                35                 664            14
# 20             16                58                  49            19
#
#     Research Rank  Score
# 1               1  100.0
# 2               9   96.7
# 3               2   95.2
# 4              11   94.1
# 5               4   93.3
# 6              82   92.6
# 7              28   92.1
# 8              13   91.6
# 9              12   91.2
# 10             21   90.8
# 11             83   90.4
# 12             16   90.1
# 13             30   89.8
# 14             23   89.5
# 15             31   89.3
# 16              7   89.1
# 17              8   88.8
# 18             15   88.6
# 19              5   88.4
# 20             24   88.2

# %%
# go back to 6th dimention --> Completeness

# %%
# go back to 6th dimention --> Completeness

# %%
# go back to 6th dimention --> Completeness

# %%
# go back to 6th dimention --> Completeness

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %%
plt.figure(figsize=(16,8))
plt.title('Top 10 Academic Ranking of World Universities')
t = sns.barplot(x='Total Score', y='University Name', data=shangahai_rank_df[:10], palette = 'viridis', width = 0.8)
t.bar_label(t.containers[0])
# Out:
# [Text(0, 0, '100'),
#  Text(0, 0, '76.8'),
#  Text(0, 0, '70.1'),
#  Text(0, 0, '69.6'),
#  Text(0, 0, '65.3'),
#  Text(0, 0, '60'),
#  Text(0, 0, '58.7'),
#  Text(0, 0, '57.2'),
#  Text(0, 0, '56.1'),
#  Text(0, 0, '55.1')]

# %%
plt.figure(figsize=(16,8))
plt.title('Top 10 Center for World University Rankings')
t = sns.barplot(x='Score', y='University Names', data=world_rank_df[:10], palette = 'viridis', width = 0.8)
t.bar_label(t.containers[0])
# Out:
# [Text(0, 0, '100'),
#  Text(0, 0, '96.7'),
#  Text(0, 0, '95.2'),
#  Text(0, 0, '94.1'),
#  Text(0, 0, '93.3'),
#  Text(0, 0, '92.6'),
#  Text(0, 0, '92.1'),
#  Text(0, 0, '91.6'),
#  Text(0, 0, '91.2'),
#  Text(0, 0, '90.8')]

# %%
top10_t = times_rank_df.head(10)
top10_t['scores'] = top10_t['scores'].astype(float)

plt.figure(figsize=(16,8))
plt.title('Top 10 Times Higher Education World University Ranking ')
t = sns.barplot(x='scores', y='University Name ', data=top10_t[:10], palette = 'viridis', width = 0.8)
t.bar_label(t.containers[0])
# Out:
# /tmp/ipykernel_45504/2175654293.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10_t['scores'] = top10_t['scores'].astype(float)
# [Text(0, 0, '99.4'),
#  Text(0, 0, '97.5'),
#  Text(0, 0, '97.2'),
#  Text(0, 0, '96.9'),
#  Text(0, 0, '96.6'),
#  Text(0, 0, '96.5'),
#  Text(0, 0, '96.4'),
#  Text(0, 0, '96.4'),
#  Text(0, 0, '95.8'),
#  Text(0, 0, '95.8')]

# %%
a = world_rank_df.sort_values(by="Employability Rank")[world_rank_df["Employability Rank"] != 0].head(10)

a[['Employability Rank', 'University Names']]
# Out:
# /tmp/ipykernel_45504/1198282621.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = world_rank_df.sort_values(by="Employability Rank")[world_rank_df["Employability Rank"] != 0].head(10)
#      Employability Rank                                   University Names
# 1                     1                                 Harvard University
# 120                   2                                             INSEAD
# 211                   3                Institut national du service public
# 3                     4                                Stanford University
# 274                   5         China Europe International Business School
# 13                    6                                University of Tokyo
# 280                   7                                          HEC Paris
# 9                     8                         University of Pennsylvania
# 45                    9                    Institut Polytechnique de Paris
# 406                  10  International Institute for Management Develop...

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.
